# %%
import seaborn as sns

# %%
df=sns.load_dataset(r"E:\CODEZ\Data Science\Data Sets\tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Tip is my depending feature. (Totalbill, sex,smoker,day are independing feature)

# %% [markdown]
# # Correlation only valid for int and float. Correlation helps to find relationship between two features like totalbill and tip

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %% [markdown]
# # Positive means one value increases other value is also increase. Negative means ones increase other will decrease

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x="tip",y="total_bill" , data=df, kind="hex")

# %%
sns.jointplot(x="tip",y="total_bill" , data=df, kind="reg")

# %%
sns.pairplot(df)

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.pairplot(df,hue="sex")

# %% [markdown]
# # JoinPlot,PairPlot,  Distplot --> Int and Float
#
# # BoxPlt, ViolinPlot, CountPlot, barPlot-->  Categorical Features (smoker,sex)

# %%
sns.countplot("sex",data=df)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot("smoker",data=df)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot("day",data=df)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(y="day",data=df) # Change the axis
# Out:
# <AxesSubplot:xlabel='count', ylabel='day'>

# %%
sns.barplot(x="sex",y="total_bill", data=df) #should define your axis properly
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.boxplot("day","total_bill",data=df)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Violin Plot ---- Help us to see both the distribution of data

# %%
sns.violinplot(x="total_bill",y="day",data=df,palette="rainbow")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>
