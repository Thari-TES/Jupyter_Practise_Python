# %%
import pandas as pd
import os
import numpy as np

# %%
url="https://www.sprint.com/en/support/solutions/international/international-mobile-dial-codes.html"
dfhtml=pd.read_html(url)

# %%
dfhtml
# Out:
# [    Country/U.S. Territories Country code  \
#  0                Afghanistan           93
#  1                    Albania          355
#  2                    Algeria          213
#  3             American Samoa      1 (684)
#  4                    Andorra          376
#  ..                       ...          ...
#  217                Venezuela           58
#  218                  Vietnam           84
#  219                    Yemen          967
#  220                   Zambia          260
#  221                 Zimbabwe          263
#
#                  Mobile dial codes (effective 8/2/2019)
#  0                                         70-72, 77-79
#  1                                                66-69
#  2                                     5-6, 77-79, 9619
#  3                                             258, 733
#  4                                               3-4, 6
#  ..                                                 ...
# ...

# %%
df=pd.read_excel("netflix.xlsx")

# %%
df
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...

# %%
df.to_pickle("Netflix")

# %%
dfpicke=pd.read_pickle("Netflix")

# %%
dfpicke
# Out:
#                        title rating  \
# 0               White Chicks  PG-13
# 1        Lucky Number Slevin      R
# 2             Grey's Anatomy  TV-14
# 3               Prison Break  TV-14
# 4      How I Met Your Mother  TV-PG
# ..                       ...    ...
# 995                  The BFG     PG
# 996  The Secret Life of Pets     PG
# 997         Precious Puppies   TV-G
# 998              Beary Tales   TV-G
# 999          Growing Up Wild      G
#
#                                            ratingLevel  ratingDescription  \
# 0    crude and sexual humor, language and some drug...                 80
# 1    strong violence, sexual content and adult lang...                100
# 2    Parents strongly cautioned. May be unsuitable ...                 90
# 3    Parents strongly cautioned. May be unsuitable ...                 90
# 4    Parental guidance suggested. May not be suitab...                 70
# ..                                                 ...                ...
# ...
